# %% [raw]
# ---
# title: "The Uncomfortable Discussion of IP, Generative AI, and Human Creativity"
# description: "The Ghibli Case Study..."
# author: "Michael Li"
# date: "3/30/2025"
# categories:
#   - LLMs
#   - prompting
#   - logic
# ---

# %% [markdown]
# ![image.png](attachment:dfb2ff8a-a022-4eee-84e0-7b3f79b863e8.png)
